# %% [markdown]
# ## LOC research

# %% [markdown]
# # Collections:
# African-American Band Music & Recordings, 1883 to 1923

# %% [markdown]
#  Import Request

# %%
import requests

# %% [markdown]
# Resquest module JSON API African-Band-Music

# %%
r = requests.get("https://www.loc.gov/collections/african-american-band-music/?fo=json")
r.json()
# Out:
# {'aka': ['aabm'],
#  'breadcrumbs': [{'Library of Congress': 'https://www.loc.gov'},
#   {'Digital Collections': 'https://www.loc.gov/collections/'},
#   {'African-American Band Music & Recordings, 1883-1923': 'https://www.loc.gov/collections/african-american-band-music/'}],
#  'categories': ['about-this-collection', 'articles-and-essays'],
#  'content': {'active': True,
#   'link': 'https://www.loc.gov/collections/african-american-band-music/',
#   'markup': None,
#   'pagination': '2 of 3',
#   'partof': [],
#   'results': [{'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010757/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010757/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010757/default.html',
#      'http://www.loc.gov/resource/ihas.100010757.0/',
#      'http://www.loc.gov/item/ihas.100010757',
#      'http://www.loc.gov/resource/ihas.100010757.0'],
#     'campaigns': [],
#     'contributor': ['[larkins, john]',
#      'amrican record co',
#      'smith, chris',
#      'invincible male quartet'],
#     'date': '1904',
#     'dates': ['1904'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 11 in. |   Arthur Collins performs. (Content).   no matrix information   Issued in 1904.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:39.887Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010757/',
#     'image_url': [],
#     'index': 1,
#     'item': {'contributor_names': ['[Larkins, John] (composer)',
#       'Smith, Chris -- 1879-1949 (composer)',
#       'Invincible Male Quartet (performer)'],
#      'created_published': ['Amrican Record Co., [1904].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 11 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' American Record Co. 031046',
#      'notes': ['Arthur Collins performs. (Content)',
#       'no matrix information',
#       'Issued in 1904.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010757/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'files': 1,
#       'url': 'https://www.loc.gov/resource/ihas.100010757.0'}],
#     'shelf_id': 'American Record Co. 031046',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:43.896Z',
#     'title': 'Shame on you',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010757/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010758/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010758/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010758/default.html',
#      'uuid://CEA2B42FB8AB0108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010758.0/',
#      'http://www.loc.gov/item/ihas.100010758',
#      'http://www.loc.gov/resource/ihas.100010758.0'],
#     'campaigns': [],
#     'contributor': ['collins, arthur',
#      '[burt, benjamin hapgood]',
#      'american record co'],
#     'date': '1904',
#     'dates': ['1904'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 11 in. |   Mx: 331   Issued in 1904   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:53.631Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010758/',
#     'image_url': [],
#     'index': 2,
#     'item': {'contributor_names': ['[Burt, Benjamin Hapgood] -- b. 1882 (composer)',
#       'Collins, Arthur (performer)'],
#      'created_published': ['American Record Co., [1904].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 11 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' American Record Co. 031075',
#      'notes': ['Mx: 331', 'Issued in 1904'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010758/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010758.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FB8AC0108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010758.0'}],
#     'shelf_id': 'American Record Co. 031075',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:43.896Z',
#     'title': 'Indians along Broadway',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010758/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010769/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010769/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010769/default.html',
#      'uuid://CEA2B42FA8770108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010769.0/',
#      'http://www.loc.gov/item/ihas.100010769',
#      'http://www.loc.gov/resource/ihas.100010769.0'],
#     'campaigns': [],
#     'contributor': ['hogan, [ernest]',
#      'gaskin, george j.',
#      'berliner grammophone'],
#     'date': '1896',
#     'dates': ['1896'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 7 in. |   Recorded on Nov. 16, 1896.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:47:04.531Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010769/',
#     'image_url': [],
#     'index': 3,
#     'item': {'contributor_names': ['Hogan, [Ernest] (composer)',
#       'Gaskin, George J. (performer)'],
#      'created_published': ['Berliner Grammophone, 1896.'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 7 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Berliner 1610',
#      'notes': ['Recorded on Nov. 16, 1896.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010769/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'rise of industrial america (1877-1900)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010769.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FA8780108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010769.0'}],
#     'shelf_id': 'Berliner 1610',
#     'site': ['performingarts'],
#     'subject': ['rise of industrial america',
#      'popular music',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:43.896Z',
#     'title': 'All coons look alike to me',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010769/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010656/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010656/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010656/default.html',
#      'uuid://CEA2B42FBC8D0108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010656.0/',
#      'http://www.loc.gov/item/ihas.100010656',
#      'http://www.loc.gov/resource/ihas.100010656.0'],
#     'campaigns': [],
#     'contributor': ['cameo dance orchestra', 'cameo', 'tyers, w[illiam]. h.'],
#     'date': '1923',
#     'dates': ['1923'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   Mx: 445-B3   Issued in early 1923.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:22.111Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010656/',
#     'image_url': [],
#     'index': 4,
#     'item': {'contributor_names': ['Tyers, W[illiam]. H. (composer)',
#       'Cameo Dance Orchestra (performer)'],
#      'created_published': ['Cameo, [1923].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Cameo 331',
#      'notes': ['Mx: 445-B3', 'Issued in early 1923.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010656/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010656.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FBC8E0108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010656.0'}],
#     'shelf_id': 'Cameo 331',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': 'Maori : Samoan dance',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010656/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010669/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010669/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010669/default.html',
#      'uuid://CEA2B42FB4BF0108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010669.0/',
#      'http://www.loc.gov/item/ihas.100010669',
#      'http://www.loc.gov/resource/ihas.100010669.0'],
#     'campaigns': [],
#     'contributor': ['[smith, chris]', 'climax band', 'columbia'],
#     'date': '1901',
#     'dates': ['1901'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 7 in. |   "Medley March" (Content).   Mx: 362   Recorded in 1901   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:39.887Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010669/',
#     'image_url': [],
#     'index': 5,
#     'item': {'contributor_names': ['[Smith, Chris] (composer)',
#       'Climax Band (performer)'],
#      'created_published': ['Columbia, [1901].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 7 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Climax 362',
#      'notes': ['"Medley March" (Content)', 'Mx: 362', 'Recorded in 1901'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010669/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010669.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FB4C00108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010669.0'}],
#     'shelf_id': 'Climax 362',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': 'Good morning Carrie',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010669/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010692/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010692/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010692/default.html',
#      'uuid://CEA2B42FCBA90108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010692.0/',
#      'http://www.loc.gov/item/ihas.100010692',
#      'http://www.loc.gov/resource/ihas.100010692.0'],
#     'campaigns': [],
#     'contributor': ['[myers, j.w.]', 'columbia'],
#     'date': '1901',
#     'dates': ['1901'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 7 in. |   "Baritone Solo" (Content).   Recorded in late 1901   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:45:43.008Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010692/',
#     'image_url': [],
#     'index': 6,
#     'item': {'contributor_names': ['[Myers, J.W.] (performer)'],
#      'created_published': ['Columbia, [1901].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 7 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Climax 571',
#      'notes': ['"Baritone Solo" (Content)', 'Recorded in late 1901'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010692/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010692.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FCBAA0108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010692.0'}],
#     'shelf_id': 'Climax 571',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': 'Way down yonder in the corn field',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010692/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010694/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010694/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010694/default.html',
#      'uuid://CEA2B42FBEDD0108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010694.0/',
#      'http://www.loc.gov/item/ihas.100010694',
#      'http://www.loc.gov/resource/ihas.100010694.0'],
#     'campaigns': [],
#     'contributor': ['[davis, gussie l.]', 'columbia', 'climax quartette'],
#     'date': '1902',
#     'dates': ['1902'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 7 in. |   Mx: 750-A   Issued in early 1902   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:45.770Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010694/',
#     'image_url': [],
#     'index': 7,
#     'item': {'contributor_names': ['[Davis, Gussie L.] -- 1863-1899 (composer)',
#       'Climax Quartette (performer)'],
#      'created_published': ['Columbia, [1902].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 7 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Climax 750',
#      'notes': ['Mx: 750-A', 'Issued in early 1902'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010694/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010694.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FBEDE0108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010694.0'}],
#     'shelf_id': 'Climax 750',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': 'My Creole Sue',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010694/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010750/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010750/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010750/default.html',
#      'uuid://CEA2B42FBE430108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010750.0/',
#      'http://www.loc.gov/item/ihas.100010750',
#      'http://www.loc.gov/resource/ihas.100010750.0'],
#     'campaigns': [],
#     'contributor': ['band', 'columbia'],
#     'date': '1902',
#     'dates': ['1902'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   Mx: 679 -2   Issued in early 1902.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:32.826Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010750/',
#     'image_url': [],
#     'index': 8,
#     'item': {'contributor_names': ['Band (performer)'],
#      'created_published': ['Columbia, [1902].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Climax K-13',
#      'notes': ['Mx: 679 -2', 'Issued in early 1902.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010750/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Parlor and Concert Stage',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010750.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FBE440108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010750.0'}],
#     'shelf_id': 'Climax K-13',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'parlor and concert stage',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:43.896Z',
#     'title': 'Morning, noon and night overture',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010750/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010748/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010748/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010748/default.html',
#      'uuid://CEA2B42FB7A10108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010748.0/',
#      'http://www.loc.gov/item/ihas.100010748',
#      'http://www.loc.gov/resource/ihas.100010748.0'],
#     'campaigns': [],
#     'contributor': ['[cole, robert]',
#      'columbia',
#      '[roberts, bob]',
#      'johnson, j. rosamond (john rosamond)'],
#     'date': '1909',
#     'dates': ['1909'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   "Baritone Solo, Orchestra Accompaniment" (Content).   Mx: 3943 [unknown take]   Recorded in late 1908 or early 1909.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:45:44.406Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010748/',
#     'image_url': [],
#     'index': 9,
#     'item': {'contributor_names': ['[Cole, Robert] (composer)',
#       'Johnson, J. Rosamond (John Rosamond) -- 1873-1954 (composer)',
#       '[Roberts, Bob] (performer)'],
#      'created_published': ['Columbia, [1909].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Climax X-246',
#      'notes': ['"Baritone Solo, Orchestra Accompaniment" (Content)',
#       'Mx: 3943 [unknown take]',
#       'Recorded in late 1908 or early 1909.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010748/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010748.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FB7A20108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010748.0'}],
#     'shelf_id': 'Climax X-246',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:43.896Z',
#     'title': "I ain't had no lovin in a long time",
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010748/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010691/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010691/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010691/default.html',
#      'uuid://CEA2B42FACAB0108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010691.0/',
#      'http://www.loc.gov/item/ihas.100010691',
#      'http://www.loc.gov/resource/ihas.100010691.0'],
#     'campaigns': [],
#     'contributor': ['[cole, robert]',
#      'columbia',
#      '[collins, arthur]',
#      'johnson, j. rosamond (john rosamond)'],
#     'date': '1901',
#     'dates': ['1901'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   "Baritone Solo" (Content).   Mx: 13 -1   Recorded in early 1901   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:28.076Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010691/',
#     'image_url': [],
#     'index': 10,
#     'item': {'contributor_names': ['[Cole, Robert] (composer)',
#       'Johnson, J. Rosamond (John Rosamond) -- 1873-1954 (composer)',
#       '[Collins, Arthur] (performer)'],
#      'created_published': ['Columbia, [1901].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Columbia 13',
#      'notes': ['"Baritone Solo" (Content)',
#       'Mx: 13 -1',
#       'Recorded in early 1901'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010691/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010691.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FACAC0108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010691.0'}],
#     'shelf_id': 'Columbia 13',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': 'Come out Dinah on the green',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010691/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010698/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010698/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010698/default.html',
#      'uuid://CEA2B42FB81F0108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010698.0/',
#      'http://www.loc.gov/item/ihas.100010698',
#      'http://www.loc.gov/resource/ihas.100010698.0'],
#     'campaigns': [],
#     'contributor': ['[rogers, alex]', 'columbia', '[roberts, bob]'],
#     'date': '1903',
#     'dates': ['1903'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 7 in. |   "Baritone Solo" (Content).   Mx: 1388 -1   Recorded in early 1903.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:04.774Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010698/',
#     'image_url': [],
#     'index': 11,
#     'item': {'contributor_names': ['[Rogers, Alex] (composer)',
#       '[Roberts, Bob] (performer)'],
#      'created_published': ['Columbia, [1903].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 7 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Columbia 1388',
#      'notes': ['"Baritone Solo" (Content)',
#       'Mx: 1388 -1',
#       'Recorded in early 1903.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010698/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010698.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FB8200108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010698.0'}],
#     'shelf_id': 'Columbia 1388',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': "I'm a Jonah man",
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010698/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010699/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010699/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010699/default.html',
#      'uuid://CEA2B42FC0030108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010699.0/',
#      'http://www.loc.gov/item/ihas.100010699',
#      'http://www.loc.gov/resource/ihas.100010699.0'],
#     'campaigns': [],
#     'contributor': ['[collins, arthur and harlan, byron g.]',
#      '[cole, robert]',
#      'columbia'],
#     'date': '1903',
#     'dates': ['1903'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   "Baritone and Tenor Duet" (Content).   Mx: 1492 -1 -9   Recorded in mid-1903.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:13.614Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010699/',
#     'image_url': [],
#     'index': 12,
#     'item': {'contributor_names': ['[Cole, Robert] (composer)',
#       '[Collins, Arthur and Harlan, Byron G.] (performer)'],
#      'created_published': ['Columbia, [1903].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Columbia 1492',
#      'notes': ['"Baritone and Tenor Duet" (Content)',
#       'Mx: 1492 -1 -9',
#       'Recorded in mid-1903.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010699/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010699.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FC0040108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010699.0'}],
#     'shelf_id': 'Columbia 1492',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': "Oh didn't he ramble",
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010699/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010759/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010759/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010759/default.html',
#      'uuid://CEA2B42FC1390108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010759.0/',
#      'http://www.loc.gov/item/ihas.100010759',
#      'http://www.loc.gov/resource/ihas.100010759.0'],
#     'campaigns': [],
#     'contributor': ['[tyers, william h.]',
#      'columbia',
#      "johnnie miller's new orleans frolickers"],
#     'date': '1928',
#     'dates': ['1928'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   take 3   Recorded on April 25, 1928   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:22.111Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010759/',
#     'image_url': [],
#     'index': 13,
#     'item': {'contributor_names': ['[Tyers, William H.] (composer)',
#       "Johnnie Miller's New Orleans Frolickers (performer)"],
#      'created_published': ['Columbia, [1928].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Columbia 1546-D',
#      'notes': ['take 3', 'Recorded on April 25, 1928'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010759/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010759.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FC13A0108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010759.0'}],
#     'shelf_id': 'Columbia 1546-D',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:43.896Z',
#     'title': 'Panama',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010759/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010724/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010724/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010724/default.html',
#      'uuid://CEA2B42FC6650108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010724.0/',
#      'http://www.loc.gov/item/ihas.100010724',
#      'http://www.loc.gov/resource/ihas.100010724.0'],
#     'campaigns': [],
#     'contributor': ['columbia', 'gaskin, george j.'],
#     'date': '1901',
#     'dates': ['1901'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 7 in. |   "Tenor Solo" (Content).   Mx: 175 -2   Recorded in 1901   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:39.403Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010724/',
#     'image_url': [],
#     'index': 14,
#     'item': {'contributor_names': ['Gaskin, George J. (performer)'],
#      'created_published': ['Columbia, [1901].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 7 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Columbia 175',
#      'notes': ['"Tenor Solo" (Content)', 'Mx: 175 -2', 'Recorded in 1901'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010724/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010724.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FC6660108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010724.0'}],
#     'shelf_id': 'Columbia 175',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': 'Sally in our alley',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010724/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010700/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010700/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010700/default.html',
#      'uuid://CEA2B42FBFC10108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010700.0/',
#      'http://www.loc.gov/item/ihas.100010700',
#      'http://www.loc.gov/resource/ihas.100010700.0'],
#     'campaigns': [],
#     'contributor': ['morgan, [corrinne] and stanley, frank',
#      '[cole, robert]',
#      'columbia',
#      'johnson, j. rosamond (john rosamond)'],
#     'date': '1904',
#     'dates': ['1904'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   "Contralto and Baritone Duet - Orchestra Accompaniment. Sung by Miss Caroline Morgan and Mr. Frank Stanley" (Content).   Mx: 1832 -3   Recorded in mid-1904.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:53.631Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010700/',
#     'image_url': [],
#     'index': 15,
#     'item': {'contributor_names': ['Johnson, J. Rosamond (John Rosamond) -- 1873-1954 (composer)',
#       '[Cole, Robert] (composer)',
#       'Morgan, [Corrinne] and Stanley, Frank (performer)'],
#      'created_published': ['Columbia, [1904].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Columbia 1832',
#      'notes': ['"Contralto and Baritone Duet - Orchestra Accompaniment. Sung by Miss Caroline Morgan and Mr. Frank Stanley" (Content)',
#       'Mx: 1832 -3',
#       'Recorded in mid-1904.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010700/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010700.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FBFC20108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010700.0'}],
#     'shelf_id': 'Columbia 1832',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': "Nobody's lookin' but de owl and de moon",
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010700/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010701/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010701/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010701/default.html',
#      'uuid://CEA2B42FAA410108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010701.0/',
#      'http://www.loc.gov/item/ihas.100010701',
#      'http://www.loc.gov/resource/ihas.100010701.0'],
#     'campaigns': [],
#     'contributor': ['[cole, robert]',
#      'columbia',
#      'myers, j.w.',
#      'johnson, j. rosamond (john rosamond)'],
#     'date': '1904',
#     'dates': ['1904'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   "Baritone Solo" (Content).   Mx: 1854-1   Recorded in mid-1904.   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:42.160Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010701/',
#     'image_url': [],
#     'index': 16,
#     'item': {'contributor_names': ['Johnson, J. Rosamond (John Rosamond) -- 1873-1954 (composer)',
#       '[Cole, Robert] (composer)',
#       'Myers, J.W. (performer)'],
#      'created_published': ['Columbia, [1904].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Columbia 1854',
#      'notes': ['"Baritone Solo" (Content)',
#       'Mx: 1854-1',
#       'Recorded in mid-1904.'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010701/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
#      'performing arts encyclopedia'],
#     'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010701.mp3',
#       'download_restricted': True,
#       'files': 1,
#       'media_object_id': 'CEA2B42FAA420108E0438C93F0280108',
#       'url': 'https://www.loc.gov/resource/ihas.100010701.0'}],
#     'shelf_id': 'Columbia 1854',
#     'site': ['performingarts'],
#     'subject': ['popular music',
#      'progressive era to new era',
#      'songs and music',
#      'popular songs of the day',
#      'music',
#      'african americans',
#      'band music'],
#     'timestamp': '2023-09-22T20:09:37.456Z',
#     'title': 'Big Indian chief',
#     'type': ['sound recording-musical'],
#     'url': 'https://www.loc.gov/item/ihas.100010701/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/item/ihas.100010666/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010666/',
#      'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010666/default.html',
#      'uuid://CEA2B42FB5DB0108E0438C93F0280108',
#      'http://www.loc.gov/resource/ihas.100010666.0/',
#      'http://www.loc.gov/item/ihas.100010666',
#      'http://www.loc.gov/resource/ihas.100010666.0'],
#     'campaigns': [],
#     'contributor': ['smith, [chris]',
#      'hein, [silvio]',
#      'columbia',
#      'williams, bert'],
#     'date': '1906',
#     'dates': ['1906'],
#     'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   Mx: 3536 -3-3. M-1225-3   Recorded c.October 1906   Sound Recording (Form).'],
#     'digitized': True,
#     'extract_timestamp': '2023-09-22T19:46:33.529Z',
#     'group': ['ihas/mets', 'performingarts'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/item/ihas.100010666/',
#     'image_url': [],
#     'index': 17,
#     'item': {'contributor_names': ['Hein, [Silvio] (composer)',
#       'Smith, [Chris] (composer)',
#       'Williams, Bert (performer)'],
#      'created_published': ['Columbia, [1906].'],
#      'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#      'form': ['sound recording'],
#      'lc_classification': ' Columbia 3536',
#      'notes': ['Mx: 3536 -3-3. M-1225-3', 'Recorded c.October 1906'],
#      'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010666/mets.xml'],
#      'place': ['United States'],
#      'subject_headings': ['African Americans -- Music',
#       'Popular music -- United States',
#       'Band music',
#       'Popular Songs of the Day',
#       'Songs and Music',
#       'Progressive Era to New Era (1900-1929)']},
#     'location': ['united states'],
#     'mime_type': ['application/x-audio'],
#     'online_format': ['audio'],
#     'original_format': ['sound recording'],
#     'other_title': [],
#     'partof': ['the library of congress celebrates the songs of america',
#      'african-american band music & recordings, 1883-1923',
# ...
#    'shelf_id': 'Columbia A 1417',
#    'site': ['performingarts'],
#    'subject': ['popular music',
#     'progressive era to new era',
#     'songs and music',
#     'popular songs of the day',
#     'music',
#     'african americans',
#     'band music'],
#    'timestamp': '2023-09-22T20:09:43.896Z',
#    'title': 'Junk man rag',
#    'type': ['sound recording-musical'],
#    'url': 'https://www.loc.gov/item/ihas.100010749/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/ihas.100010671/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010671/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010671/default.html',
#     'uuid://CEA2B42FC4770108E0438C93F0280108',
#     'http://www.loc.gov/resource/ihas.100010671.0/',
#     'http://www.loc.gov/item/ihas.100010671',
#     'http://www.loc.gov/resource/ihas.100010671.0'],
#    'campaigns': [],
#    'contributor': ['the right quintette',
#     'columbia',
#     'rogers, [alex]',
#     'cook, [will marion]'],
#    'date': '1915',
#    'dates': ['1915'],
#    'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   "Vocal Quintette" (Content).   Mx: 46303 -2   Recorded on Dec. 24, 1915   Sound Recording (Form).'],
#    'digitized': True,
#    'extract_timestamp': '2023-09-22T19:45:37.587Z',
#    'group': ['ihas/mets', 'performingarts'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/ihas.100010671/',
#    'image_url': [],
#    'index': 21,
#    'item': {'contributor_names': ['Cook, [Will Marion] (composer)',
#      'Rogers, [Alex] (lyricist)',
#      'The Right Quintette (performer)'],
#     'created_published': ['Columbia, [1915].'],
#     'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#     'form': ['sound recording'],
#     'lc_classification': ' Columbia A 1987',
#     'notes': ['"Vocal Quintette" (Content)',
#      'Mx: 46303 -2',
#      'Recorded on Dec. 24, 1915'],
#     'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010671/mets.xml'],
#     'place': ['United States'],
#     'subject_headings': ['African Americans -- Music',
#      'Popular music -- United States',
#      'Band music',
#      'Popular Songs of the Day',
#      'Songs and Music',
#      'Parlor and Concert Stage',
#      'Progressive Era to New Era (1900-1929)']},
#    'location': ['united states'],
#    'mime_type': ['application/x-audio'],
#    'online_format': ['audio'],
#    'original_format': ['sound recording'],
#    'other_title': [],
#    'partof': ['the library of congress celebrates the songs of america',
#     'african-american band music & recordings, 1883-1923',
#     'performing arts encyclopedia'],
#    'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010671.mp3',
#      'download_restricted': True,
#      'files': 1,
#      'media_object_id': 'CEA2B42FC4780108E0438C93F0280108',
#      'url': 'https://www.loc.gov/resource/ihas.100010671.0'}],
#    'shelf_id': 'Columbia A 1987',
#    'site': ['performingarts'],
#    'subject': ['popular music',
#     'progressive era to new era',
#     'songs and music',
#     'popular songs of the day',
#     'music',
#     'parlor and concert stage',
#     'african americans',
#     'band music'],
#    'timestamp': '2023-09-22T20:09:37.456Z',
#    'title': 'Rain Song',
#    'type': ['sound recording-musical'],
#    'url': 'https://www.loc.gov/item/ihas.100010671/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/ihas.100010672/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010672/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010672/default.html',
#     'uuid://CEA2B42FB2890108E0438C93F0280108',
#     'http://www.loc.gov/resource/ihas.100010672.0/',
#     'http://www.loc.gov/item/ihas.100010672',
#     'http://www.loc.gov/resource/ihas.100010672.0'],
#    'campaigns': [],
#    'contributor': ['the right quintette',
#     'columbia',
#     'rogers, [alex]',
#     'cook, [will marion]'],
#    'date': '1915',
#    'dates': ['1915'],
#    'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   "Vocal Quintette" (Content).   Mx: 46302 -1   Recorded December 24, 1915.   Sound Recording (Form).'],
#    'digitized': True,
#    'extract_timestamp': '2023-09-22T19:46:03.128Z',
#    'group': ['ihas/mets', 'performingarts'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/ihas.100010672/',
#    'image_url': [],
#    'index': 22,
#    'item': {'contributor_names': ['Cook, [Will Marion] (composer)',
#      'Rogers, [Alex] (lyricist)',
#      'The Right Quintette (performer)'],
#     'created_published': ['Columbia, [1915].'],
#     'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#     'form': ['sound recording'],
#     'lc_classification': ' Columbia A 1987',
#     'notes': ['"Vocal Quintette" (Content)',
#      'Mx: 46302 -1',
#      'Recorded December 24, 1915.'],
#     'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010672/mets.xml'],
#     'place': ['United States'],
#     'subject_headings': ['African Americans -- Music',
#      'Popular music -- United States',
#      'Band music',
#      'Popular Songs of the Day',
#      'Songs and Music',
#      'Parlor and Concert Stage',
#      'Progressive Era to New Era (1900-1929)']},
#    'location': ['united states'],
#    'mime_type': ['application/x-audio'],
#    'online_format': ['audio'],
#    'original_format': ['sound recording'],
#    'other_title': [],
#    'partof': ['the library of congress celebrates the songs of america',
#     'african-american band music & recordings, 1883-1923',
#     'performing arts encyclopedia'],
#    'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010672.mp3',
#      'download_restricted': True,
#      'files': 1,
#      'media_object_id': 'CEA2B42FB28A0108E0438C93F0280108',
#      'url': 'https://www.loc.gov/resource/ihas.100010672.0'}],
#    'shelf_id': 'Columbia A 1987',
#    'site': ['performingarts'],
#    'subject': ['popular music',
#     'progressive era to new era',
#     'songs and music',
#     'popular songs of the day',
#     'music',
#     'parlor and concert stage',
#     'african americans',
#     'band music'],
#    'timestamp': '2023-09-22T20:09:37.456Z',
#    'title': 'Exhortation',
#    'type': ['sound recording-musical'],
#    'url': 'https://www.loc.gov/item/ihas.100010672/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/ihas.100010645/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010645/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010645/default.html',
#     'uuid://CEA2B42FCD710108E0438C93F0280108',
#     'http://www.loc.gov/resource/ihas.100010645.0/',
#     'http://www.loc.gov/item/ihas.100010645',
#     'http://www.loc.gov/resource/ihas.100010645.0'],
#    'campaigns': [],
#    'contributor': ['cawley, [joe]',
#     'nunez, [al]',
#     'columbia',
#     'louisiana five jazz orchestra',
#     'lada, [anton]'],
#    'date': '1919',
#    'dates': ['1919'],
#    'description': ['sound recording |   1 sound disc: analog, 80 rpm, mono. ; 10 in. |   "Introducing: Foot-Warmer" (Content).   Recorded April 1, 1919.   Mx: 78337 -2   Sound Recording (Form).'],
#    'digitized': True,
#    'extract_timestamp': '2023-09-22T19:46:01.593Z',
#    'group': ['ihas/mets', 'performingarts'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/ihas.100010645/',
#    'image_url': [],
#    'index': 23,
#    'item': {'contributor_names': ['Lada, [Anton] (composer)',
#      'Nunez, [Al] (composer)',
#      'Louisiana Five Jazz Orchestra (performer)',
#      'Cawley, [Joe]'],
#     'created_published': ['Columbia, [1919].'],
#     'extent': ['1 sound disc: analog, 80 rpm, mono. ; 10 in.'],
#     'form': ['sound recording'],
#     'lc_classification': ' Columbia A 2742',
#     'notes': ['"Introducing: Foot-Warmer" (Content)',
#      'Recorded April 1, 1919.',
#      'Mx: 78337 -2'],
#     'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010645/mets.xml'],
#     'place': ['United States'],
#     'subject_headings': ['African Americans -- Music',
#      'Popular music -- United States',
#      'Band music',
#      'Popular Songs of the Day',
#      'Songs and Music',
#      'Progressive Era to New Era (1900-1929)']},
#    'location': ['united states'],
#    'mime_type': ['application/x-audio'],
#    'online_format': ['audio'],
#    'original_format': ['sound recording'],
#    'other_title': [],
#    'partof': ['the library of congress celebrates the songs of america',
#     'african-american band music & recordings, 1883-1923',
#     'performing arts encyclopedia'],
#    'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010645.mp3',
#      'download_restricted': True,
#      'files': 1,
#      'media_object_id': 'CEA2B42FCD720108E0438C93F0280108',
#      'url': 'https://www.loc.gov/resource/ihas.100010645.0'}],
#    'shelf_id': 'Columbia A 2742',
#    'site': ['performingarts'],
#    'subject': ['popular music',
#     'progressive era to new era',
#     'songs and music',
#     'popular songs of the day',
#     'music',
#     'african americans',
#     'band music'],
#    'timestamp': '2023-09-22T20:09:37.456Z',
#    'title': 'Yelping hound blues',
#    'type': ['sound recording-musical'],
#    'url': 'https://www.loc.gov/item/ihas.100010645/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/ihas.100010791/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010791/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010791/default.html',
#     'uuid://CEA2B42FC6F90108E0438C93F0280108',
#     'http://www.loc.gov/resource/ihas.100010791.0/',
#     'http://www.loc.gov/item/ihas.100010791',
#     'http://www.loc.gov/resource/ihas.100010791.0'],
#    'campaigns': [],
#    'contributor': ['westphal, frank and his rainbo orchestra',
#     'sissle, [noble]',
#     'columbia',
#     'blake, [eubie]'],
#    'date': '1922',
#    'dates': ['1922'],
#    'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 10 in. |   "Fox Trot" (Content).   Mx: 80386 -2   Recorded on June 12, 1922.   Sound Recording (Form).'],
#    'digitized': True,
#    'extract_timestamp': '2023-09-22T19:46:34.618Z',
#    'group': ['ihas/mets', 'performingarts'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/ihas.100010791/',
#    'image_url': [],
#    'index': 24,
#    'item': {'contributor_names': ['Sissle, [Noble] -- 1889-1975 (composer)',
#      'Blake, [Eubie] -- 1887-1983 (composer)',
#      'Westphal, Frank and His Rainbo Orchestra (performer)'],
#     'created_published': ['Columbia, [1922].'],
#     'extent': ['1 sound disc: analog, 78 rpm, mono. ; 10 in.'],
#     'form': ['sound recording'],
#     'lc_classification': ' Columbia A 3654',
#     'notes': ['"Fox Trot" (Content)',
#      'Mx: 80386 -2',
#      'Recorded on June 12, 1922.'],
#     'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010791/mets.xml'],
#     'place': ['United States'],
#     'subject_headings': ['African Americans -- Music',
#      'Popular music -- United States',
#      'Band music',
#      'Popular Songs of the Day',
#      'Songs and Music',
#      'Progressive Era to New Era (1900-1929)']},
#    'location': ['united states'],
#    'mime_type': ['application/x-audio'],
#    'online_format': ['audio'],
#    'original_format': ['sound recording'],
#    'other_title': [],
#    'partof': ['the library of congress celebrates the songs of america',
#     'african-american band music & recordings, 1883-1923',
#     'performing arts encyclopedia'],
#    'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010791.mp3',
#      'download_restricted': True,
#      'files': 1,
#      'media_object_id': 'CEA2B42FC6FA0108E0438C93F0280108',
#      'url': 'https://www.loc.gov/resource/ihas.100010791.0'}],
#    'shelf_id': 'Columbia A 3654',
#    'site': ['performingarts'],
#    'subject': ['popular music',
#     'progressive era to new era',
#     'songs and music',
#     'popular songs of the day',
#     'music',
#     'african americans',
#     'band music'],
#    'timestamp': '2023-09-22T20:09:43.896Z',
#    'title': 'Serenade blues',
#    'type': ['sound recording-musical'],
#    'url': 'https://www.loc.gov/item/ihas.100010791/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/item/ihas.100010665/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010665/',
#     'http://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010665/default.html',
#     'uuid://CEA2B42FA87D0108E0438C93F0280108',
#     'http://www.loc.gov/resource/ihas.100010665.0/',
#     'http://www.loc.gov/item/ihas.100010665',
#     'http://www.loc.gov/resource/ihas.100010665.0'],
#    'campaigns': [],
#    'contributor': ['smith', 'columbia', 'macpherson', 'williams, bert'],
#    'date': '1906',
#    'dates': ['1906'],
#    'description': ['sound recording |   1 sound disc: analog, 78 rpm, mono. ; 12 in. |   Mx: 30039 -2, vinyl test pressing   Recorded c. Sep. 26, 1906   Sound Recording (Form).'],
#    'digitized': True,
#    'extract_timestamp': '2023-09-22T19:46:57.768Z',
#    'group': ['ihas/mets', 'performingarts'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/item/ihas.100010665/',
#    'image_url': [],
#    'index': 25,
#    'item': {'contributor_names': ['MacPherson (composer)',
#      'Smith (composer)',
#      'Williams, Bert (performer)'],
#     'created_published': ['Columbia, [1906].'],
#     'extent': ['1 sound disc: analog, 78 rpm, mono. ; 12 in.'],
#     'form': ['sound recording'],
#     'lc_classification': ' Columbia A 5031',
#     'notes': ['Mx: 30039 -2, vinyl test pressing',
#      'Recorded c. Sep. 26, 1906'],
#     'other_formats': ['https://lcweb2.loc.gov/diglib/ihas/loc.natlib.ihas.100010665/mets.xml'],
#     'place': ['United States'],
#     'subject_headings': ['African Americans -- Music',
#      'Popular music -- United States',
#      'Band music',
#      'Popular Songs of the Day',
#      'Songs and Music',
#      'Progressive Era to New Era (1900-1929)']},
#    'location': ['united states'],
#    'mime_type': ['application/x-audio'],
#    'online_format': ['audio'],
#    'original_format': ['sound recording'],
#    'other_title': [],
#    'partof': ['the library of congress celebrates the songs of america',
#     'african-american band music & recordings, 1883-1923',
#     'performing arts encyclopedia'],
#    'resources': [{'audio': 'https://tile.loc.gov/storage-services/media/ingested/api/loc.natlib.ihas.100010665.mp3',
#      'download_restricted': True,
#      'files': 1,
#      'media_object_id': 'CEA2B42FA87E0108E0438C93F0280108',
#      'url': 'https://www.loc.gov/resource/ihas.100010665.0'}],
#    'shelf_id': 'Columbia A 5031',
#    'site': ['performingarts'],
#    'subject': ['popular music',
#     'progressive era to new era',
#     'songs and music',
#     'popular songs of the day',
#     'music',
#     'african americans',
#     'band music'],
#    'timestamp': '2023-09-22T20:09:37.456Z',
#    'title': 'All in out and down',
#    'type': ['sound recording-musical'],
#    'url': 'https://www.loc.gov/item/ihas.100010665/'}],
#  'search': {'dates': None,
#   'facet_limits': '',
#   'field': None,
#   'hits': 363,
#   'in': 'partof:african-american band music & recordings, 1883-1923',
#   'query': '',
#   'recommended': 0,
#   'site': {},
#   'sort_by': None,
#   'type': 'search',
#   'union_facets': '',
#   'url': 'https://www.loc.gov/collections/african-american-band-music/?fo=json'},
#  'shards': ['00'],
#  'site_type': 'collections',
#  'subjects': ['American History',
#   'African American History',
#   'Arts and Culture',
#   'Performing Arts',
#   'Music'],
#  'timestamp': 1707910393123,
#  'title': 'African-American Band Music & Recordings, 1883-1923',
#  'topics': ['African American History', 'Performing Arts'],
#  'total': 363,
#  'views': {'brief': 'https://www.loc.gov/collections/african-american-band-music/?fo=json&st=brief',
#   'current': 'list',
#   'gallery': 'https://www.loc.gov/collections/african-american-band-music/?fo=json&st=gallery',
#   'grid': 'https://www.loc.gov/collections/african-american-band-music/?fo=json&st=grid',
#   'list': 'https://www.loc.gov/collections/african-american-band-music/?fo=json',
#   'slideshow': 'https://www.loc.gov/collections/african-american-band-music/?fo=json&st=slideshow'}}

# %% [markdown]
#  Titles of the Library of Congress collections/African-Band-Music

# %%
collections_json = requests.get("https://www.loc.gov/collections/african-american-band-music/?fo=json").json()
for collections in collections_json["results"]:
    print(collections["title"])
# Out:
# Shame on you
# Indians along Broadway
# All coons look alike to me
# Maori : Samoan dance
# Good morning Carrie
# Way down yonder in the corn field
# My Creole Sue
# Morning, noon and night overture
# I ain't had no lovin in a long time
# Come out Dinah on the green
# I'm a Jonah man
# Oh didn't he ramble
# Panama
# Sally in our alley
# Nobody's lookin' but de owl and de moon
# Big Indian chief
# He's a cousin of mine
# Love's menu (Menu d'amour) : Intermezzo
# My Creole Sue
# Junk man rag
# Rain Song
# Exhortation
# Yelping hound blues
# Serenade blues
# All in out and down

# %%
from IPython.display import display

# %%
from IPython.display import Image
