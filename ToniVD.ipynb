# %% [markdown]
# #         JSON Format API: Garden and Forest Collection
#
# *A Journal of Horticulture, Landscape Art, and Forestry*

# %% [markdown]
# Import the requests module to make HTTP requests to the LOC JSON API:

# %%
import requests

# %% [markdown]
# Request JSON data and check status:

# %%
r = requests.get("https://www.loc.gov/collections/garden-and-forest/?fo=json")
r.status_code
# Out:
# 200

# %% [markdown]
# Check reponse data type:

# %%
garden_forest = r.json()
type(garden_forest)
# Out:
# dict

# %% [markdown]
# Display the JSON reponse to the request:

# %%
garden_forest
# Out:
# {'aka': ['https://lccn.loc.gov/05040093'],
#  'breadcrumbs': [{'Library of Congress': 'https://www.loc.gov'},
#   {'Digital Collections': 'https://www.loc.gov/collections/'},
#   {'Garden and Forest': 'https://www.loc.gov/collections/garden-and-forest/'}],
#  'categories': ['about-this-collection', 'articles-and-essays'],
#  'content': {'active': True,
#   'link': 'https://www.loc.gov/collections/garden-and-forest/',
#   'markup': None,
#   'pagination': '2 of 3',
#   'partof': [],
#   'results': [{'access_restricted': False,
#     'aka': ['http://lccn.loc.gov/05040093',
#      'http://www.loc.gov/item/05040093/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v01',
#      'http://www.loc.gov/resource/gdclccn.05040093_v01/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v02',
#      'http://www.loc.gov/resource/gdclccn.05040093_v02/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v03',
#      'http://www.loc.gov/resource/gdclccn.05040093_v03/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v04',
#      'http://www.loc.gov/resource/gdclccn.05040093_v04/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v05',
#      'http://www.loc.gov/resource/gdclccn.05040093_v05/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v06',
#      'http://www.loc.gov/resource/gdclccn.05040093_v06/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v07',
#      'http://www.loc.gov/resource/gdclccn.05040093_v07/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v08',
#      'http://www.loc.gov/resource/gdclccn.05040093_v08/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v09',
#      'http://www.loc.gov/resource/gdclccn.05040093_v09/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v10',
#      'http://www.loc.gov/resource/gdclccn.05040093_v10/'],
#     'campaigns': [],
#     'contributor': ['sargent, charles sprague'],
#     'date': '1888',
#     'dates': ['[1888 TO 1897]'],
#     'description': ['"A journal of horticulture, landscape art, and forestry."'],
#     'digitized': True,
#     'extract_timestamp': '2024-01-06T19:13:38.037Z',
#     'group': ['gdc/scd',
#      'gardforest',
#      'general-collections-scan-on-demand-new',
#      'garden-and-forest'],
#     'hassegments': True,
#     'id': 'http://www.loc.gov/item/05040093/',
#     'image_url': ['https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:01:05040093_v01:0001/full/pct:6.25/0/default.jpg',
#      'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:01:05040093_v01:0001/full/pct:6.25/0/default.jpg#h=451&w=318',
#      'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:01:05040093_v01:0001/full/pct:12.5/0/default.jpg#h=902&w=636',
#      'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:01:05040093_v01:0001/full/pct:25/0/default.jpg#h=1804&w=1272',
#      'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:01:05040093_v01:0001/full/pct:50/0/default.jpg#h=3608&w=2544',
#      'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:01:05040093_v01:0001/full/pct:100/0/default.jpg#h=7216&w=5088'],
#     'index': 1,
#     'item': {'call_number': ['SB1 .G2'],
#      'contributors': ['Sargent, Charles Sprague, 1841-1927, editor'],
#      'created_published': ['New York, Garden and Forest Pub. Co., 1888-1897.'],
#      'date': '1888',
#      'digital_id': ['http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v01',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v02',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v03',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v04',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v05',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v06',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v07',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v08',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v09',
#       'http://hdl.loc.gov/loc.gdc/gdclccn.05040093_v10'],
#      'format': ['periodical'],
#      'genre': ['Periodicals'],
#      'language': ['eng'],
#      'medium': ['10 volumes illustrations 32 cm'],
#      'notes': ['Weekly',
#       'v. 1-10; Feb. 20, 1888-Dec. 29, 1897.',
#       'Volumes for Feb. 20, 1888- conducted by Charles S. Sargent.',
#       'Digitized images of the entire run of this serial are available via the Internet.'],
#      'subjects': ['Botany--Periodicals',
#       'Gardening--Periodicals',
#       'Forests and forestry--Periodicals',
#       'Botany',
#       'Forests and forestry',
#       'Gardening'],
#      'summary': ['"A journal of horticulture, landscape art, and forestry."'],
#      'title': 'Garden and forest'},
#     'language': ['english'],
#     'mime_type': ['application/pdf',
#      'text/plain',
#      'image/jpeg',
#      'image/jp2',
#      'image/tiff'],
#     'number': ['4753674',
#      '2023-12-17t10:38:21',
#      '0889-874x',
#      '05040093',
#      '2020-06-16t14:06:13'],
#     'number_issn': ['0889-874x'],
#     'number_lccn': ['05040093'],
#     'number_oclc': ['4753674'],
#     'number_source_modified': ['2023-12-17t10:38:21', '2020-06-16t14:06:13'],
#     'online_format': ['pdf', 'online text', 'image'],
#     'original_format': ['periodical'],
#     'other_title': [],
#     'partof': ['catalog', 'general collections', 'garden and forest'],
#     'publication_frequency': ['weekly'],
#     'resources': [{'caption': 'Volume 1',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/01/05040093_v01/captions.txt',
#       'files': 724,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:01:05040093_v01:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/01/05040093_v01/05040093_v01.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v01/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 724,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v01/'},
#      {'caption': 'Volume 2',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/02/05040093_v02/captions.txt',
#       'files': 872,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:02:05040093_v02:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/02/05040093_v02/05040093_v02.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v02/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 872,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v02/'},
#      {'caption': 'Volume 3',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/03/05040093_v03/captions.txt',
#       'files': 880,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:03:05040093_v03:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/03/05040093_v03/05040093_v03.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v03/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 880,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v03/'},
#      {'caption': 'Volume 4',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/04/05040093_v04/captions.txt',
#       'files': 872,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:04:05040093_v04:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/04/05040093_v04/05040093_v04.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v04/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 872,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v04/'},
#      {'caption': 'Volume 5',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/05/05040093_v05/captions.txt',
#       'files': 930,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:05:05040093_v05:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/05/05040093_v05/05040093_v05.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v05/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 930,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v05/'},
#      {'caption': 'Volume 6',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/06/05040093_v06/captions.txt',
#       'files': 866,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:06:05040093_v06:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/06/05040093_v06/05040093_v06.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v06/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 866,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v06/'},
#      {'caption': 'Volume 7',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/07/05040093_v07/captions.txt',
#       'files': 812,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:07:05040093_v07:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/07/05040093_v07/05040093_v07.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v07/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 812,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v07/'},
#      {'caption': 'Volume 8',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/08/05040093_v08/captions.txt',
#       'files': 808,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:08:05040093_v08:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/08/05040093_v08/05040093_v08.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v08/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 808,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v08/'},
#      {'caption': 'Volume 9',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/09/05040093_v09/captions.txt',
#       'files': 828,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:09:05040093_v09:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/09/05040093_v09/05040093_v09.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v09/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 828,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v09/'},
#      {'caption': 'Volume 10',
#       'captions': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/10/05040093_v10/captions.txt',
#       'files': 804,
#       'fulltext_file': 'page level only',
#       'image': 'https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:10:05040093_v10:0001/full/pct:6.25/0/default.jpg',
#       'pdf': 'https://tile.loc.gov/storage-services/service/gdc/gdclccn/05/04/00/93/_v/10/05040093_v10/05040093_v10.pdf',
#       'search': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v10/&fo=json&sb=shelf-id&st=gallery',
#       'segments': 804,
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v10/'}],
#     'segments': [{'count': 724,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v01/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v01/'},
#      {'count': 866,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v06/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v06/'},
#      {'count': 812,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v07/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v07/'},
#      {'count': 808,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v08/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v08/'},
#      {'count': 828,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v09/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v09/'},
#      {'count': 872,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v04/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v04/'},
#      {'count': 930,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v05/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v05/'},
#      {'count': 804,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v10/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v10/'},
#      {'count': 872,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v02/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v02/'},
#      {'count': 880,
#       'link': 'https://www.loc.gov/collections/garden-and-forest/?fa=segmentof:gdclccn.05040093_v03/&fo=json&sb=shelf-id&st=gallery',
#       'url': 'https://www.loc.gov/resource/gdclccn.05040093_v03/'}],
#     'shelf_id': 'SB1 .G2',
#     'site': ['catalog'],
#     'subject': ['botany', 'gardening', 'periodicals', 'forests and forestry'],
#     'timestamp': '2024-01-06T20:54:16.791Z',
#     'title': 'Garden and forest',
#     'type': ['periodical'],
#     'url': 'https://www.loc.gov/item/05040093/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/about-this-collection/',
#      'https://lccn.loc.gov/05040093',
#      'https://www.loc.gov/item/05040093',
#      'http://lccn.loc.gov/05040093',
#      'http://www.loc.gov/item/05040093/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v01',
#      'http://www.loc.gov/resource/gdclccn.05040093_v01/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v02',
#      'http://www.loc.gov/resource/gdclccn.05040093_v02/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v03',
#      'http://www.loc.gov/resource/gdclccn.05040093_v03/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v04',
#      'http://www.loc.gov/resource/gdclccn.05040093_v04/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v05',
#      'http://www.loc.gov/resource/gdclccn.05040093_v05/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v06',
#      'http://www.loc.gov/resource/gdclccn.05040093_v06/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v07',
#      'http://www.loc.gov/resource/gdclccn.05040093_v07/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v08',
#      'http://www.loc.gov/resource/gdclccn.05040093_v08/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v09',
#      'http://www.loc.gov/resource/gdclccn.05040093_v09/',
#      'https://hdl.loc.gov/loc.gdc/gdclccn.05040093_v10',
#      'http://www.loc.gov/resource/gdclccn.05040093_v10/'],
#     'campaigns': [],
#     'contributor': ['sargent, charles sprague'],
#     'count': 11,
#     'date': '1888',
#     'dates': ['[1888 TO 1897]'],
#     'description': ['Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry (1888-1897) was the first American journal devoted to horticulture, botany, landscape design and preservation, national and urban park development, scientific forestry, and the conservation of forest resources. The journal was established by Charles Sprague Sargent (1841-1927), the founding director of the Arnold Arboretum of Harvard University. Though the journal was published independently, Sargent considered the weekly magazine the organ of the Arboretum.'],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:11:38.733Z',
#     'group': ['collections-portal'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/about-this-collection/',
#     'image_url': ['https://www.loc.gov/static/collections/garden-and-forest/500_500.jpg'],
#     'index': 2,
#     'item': {'call_number': ['SB1 .G2'],
#      'contributors': ['Sargent, Charles Sprague, 1841-1927, editor'],
#      'created_published': ['New York, Garden and Forest Pub. Co., 1888-1897.'],
#      'date': '1888',
#      'format': ['periodical'],
#      'genre': ['Periodicals'],
#      'language': ['eng'],
#      'medium': ['10 volumes illustrations 32 cm'],
#      'notes': ['Weekly',
#       'v. 1-10; Feb. 20, 1888-Dec. 29, 1897.',
#       'Volumes for Feb. 20, 1888- conducted by Charles S. Sargent.',
#       'Digitized images of the entire run of this serial are available via the Internet.'],
#      'subjects': ['Botany--Periodicals',
#       'Gardening--Periodicals',
#       'Forests and forestry--Periodicals',
#       'Botany',
#       'Forests and forestry',
#       'Gardening'],
#      'summary': ['"A journal of horticulture, landscape art, and forestry."'],
#      'title': 'Garden and forest'},
#     'items': 'https://www.loc.gov/collections/garden-and-forest/',
#     'language': ['english'],
#     'number': ['4753674', '2023-12-17t10:38:21', '0889-874x', '05040093'],
#     'number_issn': ['0889-874x'],
#     'number_lccn': ['05040093'],
#     'number_oclc': ['4753674'],
#     'number_source_modified': ['2023-12-17t10:38:21'],
#     'original_format': ['collection'],
#     'other_title': [],
#     'partof': ['digital collections',
#      'science, technology and business division',
#      'garden and forest'],
#     'publication_frequency': ['weekly'],
#     'resources': [],
#     'shelf_id': '~/collections/garden-and-forest/about-this-collection/',
#     'subject': ['horticulture',
#      'botany',
#      'park development',
#      'gardening',
#      'forests and forestry',
#      'science',
#      'science & technology',
#      'periodicals',
#      'landscape design',
#      'art & architecture'],
#     'subject_topic': ['science & technology', 'art & architecture'],
#     'timestamp': '2024-02-13T09:40:08.880Z',
#     'title': 'Garden and Forest',
#     'type': ['collection'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/about-this-collection/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/about-this-collection/rights-and-access/'],
#     'campaigns': [],
#     'description': ['The original Garden and Forest scans in this collection are in the public domain. The Library has obtained permission for the use of the essays in the collection, which may be subject to copyright.'],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/about-this-collection/rights-and-access/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 3,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/about-this-collection/rights-and-access/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': 'Rights and Access',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/about-this-collection/rights-and-access/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/'],
#     'campaigns': [],
#     'description': ['Top of page Skip to main content Library of Congress Search Everything Audio Recordings Books/Printed Material Films, Videos Legislation Manuscripts/Mixed Material Maps Notated Music Newspapers Periodicals Personal Narratives Photos, Prints, Drawings Software, E-Resources Web Archives'],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 4,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/articles-and-essays/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': 'Articles and Essays',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/'],
#     'campaigns': [],
#     'description': ["Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry was the first digital reformatting project done by the Library of Congress's Preservation Reformatting Division. It was also the first serial digitized in its entirety by LC. This digital-reformatting project represented the addition of digital technology to the list of options available for crafting preservation strategies for Library collections."],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 5,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': 'Digitizing and Delivery – The History of the Resource at the Library of Congress and the University of Michigan',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/'],
#     'campaigns': [],
#     'description': ['Laura Wood Roper notes in her 1973 biography of Frederick Law Olmsted that the 1890s were years of "staggering reverses" for the profession of landscape architecture. But it was also during this period that a body of theory and technical expertise was developed and became the basis for training landscape architects.'],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 6,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': '<em>Garden and Forest</em> and "Landscape Art"',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/'],
#     'campaigns': [],
#     'description': ['On February 29, 1888, the weekly periodical, Garden and Forest, A Journal of Horticulture, Landscape Art and Forestry, was inaugurated. Rather oddly, the statement outlining the purpose of the new publication, along with an extensive list of future contributors, was relegated to a page in the advertising section that preceded the main text.'],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 7,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': 'Garden and Forest: The Botanical Basis of It All',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/'],
#     'campaigns': [],
#     'description': ['While acknowledging that it was a "first-rate publication," deftly edited by the talented journalist William A. Stiles, and conceding that it was "an immediate success," Stephanne B. Sutton also contrasted the effusive praise it received with its lack of "popularity"; the plaudits may have been "gratifying," but a larger circulation would have eased the journal\'s incessant "financial crisis."'],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 8,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': 'A High-grade Paper: Garden & Forest and Nineteenth-Century American Forestry',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/'],
#     'campaigns': [],
#     'description': ["<em>Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry</em> made its debut on February 29, 1888, and ceased publication on December 29, 1897. Although financially strapped from the beginning, <em>Garden and Forest</em>'s influence spread far beyond its small circulation and brief ten-year run."],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 9,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': 'Historical Background of <em>Garden and Forest</em>',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/'],
#     'campaigns': [],
#     'description': ["<em>Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry</em>, the brainchild of the Arnold Arboretum's first director, Charles Sprague Sargent, was published during a period (1888–1897) when the science of everything that grows—wild or cultivated—was still (barely) considered a single discipline."],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 10,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': 'The Influence of <em>Garden and Forest</em> on the Development of Horticulture',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/'},
#    {'access_restricted': False,
#     'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/'],
#     'campaigns': [],
#     'description': ["Credit for the graceful prose and for the eloquent advocacy for public parks should go not to Charles Sprague Sargent, but to Garden and Forest's editor William Stiles."],
#     'digitized': True,
#     'extract_timestamp': '2024-02-13T06:24:29.053Z',
#     'group': ['cms', 'managed-content'],
#     'hassegments': False,
#     'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/',
#     'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#     'index': 11,
#     'language': ['english'],
#     'original_format': ['web page'],
#     'other_title': [],
#     'partof': ['garden and forest'],
#     'shelf_id': '~/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/',
#     'site': ['cms'],
#     'timestamp': '2024-02-13T09:41:03.181Z',
#     'title': '"Master of a Felicitous English Style": William Augustus Stiles, Editor of <em>Garden and Forest</em>',
#     'type': ['web page'],
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/'}],
#   'slug': '',
#   'title': 'Collection Items',
#   'url': 'https://www.loc.gov/collections/garden-and-forest/'},
#  'content_is_post': False,
#  'digitized': 117,
#  'expert_resources': [{'title': 'Science and Business Reading Room',
#    'url': 'https://www.loc.gov/research-centers/science-and-business'}],
#  'facet_trail': [{'facet': 'Part of',
#    'field': 'partof',
#    'superset': 'https://www.loc.gov/search/?fo=json',
#    'value': 'garden and forest'},
#   {'facet': 'Available Online',
#    'field': 'digitized',
#    'superset': 'https://www.loc.gov/collections/garden-and-forest/?all=true&fo=json',
#    'value': 'digitized'}],
#  'facet_views': {'calendar': 'https://www.loc.gov/collections/garden-and-forest/?fo=json&fs=calendar',
#   'chart': 'https://www.loc.gov/collections/garden-and-forest/?fo=json&fs=chart',
#   'current': 'list',
#   'list': 'https://www.loc.gov/collections/garden-and-forest/?fo=json'},
#  'facets': [{'filters': [{'count': 11,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fo=json',
#      'title': 'true'}],
#    'title': 'Available Online',
#    'type': 'digitized'},
#   {'filters': [{'count': 9,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=original-format!:web+page&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=original-format:web+page&fo=json',
#      'title': 'web page'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=original-format!:periodical&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=original-format:periodical&fo=json',
#      'title': 'periodical'}],
#    'title': 'Original Format',
#    'type': 'original-format'},
#   {'filters': [{'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=online-format!:image&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=online-format:image&fo=json',
#      'title': 'image'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=online-format!:online+text&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=online-format:online+text&fo=json',
#      'title': 'online text'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=online-format!:pdf&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=online-format:pdf&fo=json',
#      'title': 'pdf'}],
#    'title': 'Online Format',
#    'type': 'online-format'},
#   {'filters': [{'count': 2,
#      'not': None,
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?dates=1800/1899&fo=json',
#      'term': '1800-01-01T00:00:00Z',
#      'title': '1800 to 1899'}],
#    'title': 'Date',
#    'type': 'dates'},
#   {'filters': [{'count': 11,
#      'not': None,
#      'off': 'https://www.loc.gov/search/?fo=json',
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fo=json',
#      'title': 'garden and forest'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=partof!:catalog&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=partof:catalog&fo=json',
#      'title': 'catalog'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=partof!:digital+collections&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=partof:digital+collections&fo=json',
#      'title': 'digital collections'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=partof!:general+collections&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=partof:general+collections&fo=json',
#      'title': 'general collections'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=partof!:science,+technology+and+business+division&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=partof:science,+technology+and+business+division&fo=json',
#      'title': 'science, technology and business division'}],
#    'title': 'Part of',
#    'type': 'partof'},
#   {'filters': [{'count': 2,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=contributor!:sargent,+charles+sprague&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=contributor:sargent,+charles+sprague&fo=json',
#      'title': 'sargent, charles sprague'}],
#    'title': 'Contributor',
#    'type': 'contributor'},
#   {'filters': [{'count': 2,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:botany&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:botany&fo=json',
#      'title': 'botany'},
#     {'count': 2,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:forests+and+forestry&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:forests+and+forestry&fo=json',
#      'title': 'forests and forestry'},
#     {'count': 2,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:gardening&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:gardening&fo=json',
#      'title': 'gardening'},
#     {'count': 2,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:periodicals&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:periodicals&fo=json',
#      'title': 'periodicals'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:art+%26+architecture&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:art+%26+architecture&fo=json',
#      'title': 'art & architecture'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:horticulture&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:horticulture&fo=json',
#      'title': 'horticulture'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:landscape+design&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:landscape+design&fo=json',
#      'title': 'landscape design'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:park+development&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:park+development&fo=json',
#      'title': 'park development'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:science&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:science&fo=json',
#      'title': 'science'},
#     {'count': 1,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject!:science+%26+technology&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=subject:science+%26+technology&fo=json',
#      'title': 'science & technology'}],
#    'index': 'https://www.loc.gov/collections/garden-and-forest/index/subject/?fo=json',
#    'title': 'Subject',
#    'type': 'subject'},
#   {'filters': [{'count': 11,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=language!:english&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=language:english&fo=json',
#      'title': 'english'}],
#    'title': 'Language',
#    'type': 'language'},
#   {'filters': [{'count': 11,
#      'not': 'https://www.loc.gov/collections/garden-and-forest/?fa=access-restricted!:false&fo=json',
#      'off': None,
#      'on': 'https://www.loc.gov/collections/garden-and-forest/?fa=access-restricted:false&fo=json',
#      'title': 'false'}],
#    'title': 'Access Condition',
#    'type': 'access-restricted'}],
#  'featured_items': [{'image': '/static/collections/garden-and-forest/images/featured-lilium-grayi.jpg',
#    'title': 'Lilium Grayi (Garden and Forest Vol. 1, Issue 2)',
#    'url': '/resource/gdclccn.05040093_v01/?sp=39'},
#   {'image': '/static/collections/garden-and-forest/images/featured-flower-border.jpg',
#    'title': 'A Well-Arranged Flower Border (Garden and Forest Vol. 1, Issue 12)',
#    'url': '/resource/gdclccn.05040093_v01/?sp=197'},
#   {'image': '/static/collections/garden-and-forest/images/featured-advertisments-2-49.jpg',
#    'title': 'Advertisements (Garden and Forest Vol. 2, Issue 49)',
#    'url': '/resource/gdclccn.05040093_v02/?sp=95'},
#   {'image': '/static/collections/garden-and-forest/images/featured-hydrangea.jpg',
#    'title': 'Hydrangea vestita, var. pubescens. (Garden and Forest Vol. 3, Issue 98)',
#    'url': '/resource/gdclccn.05040093_v03/?sp=35'},
#   {'image': '/static/collections/garden-and-forest/images/featured-hybrid-calathe.jpg',
#    'title': 'A Hybrid Calanthe (Garden and Forest Vol. 4, Issue 151)',
#    'url': '/resource/gdclccn.05040093_v04/?sp=35'},
#   {'image': '/static/collections/garden-and-forest/images/featured-lake-yumoto.jpg',
#    'title': 'Lake Yumoto, Japan, with Hemlock Forests (Garden and Forest Vol. 6, Issue 257)',
#    'url': '/resource/gdclccn.05040093_v06/?sp=75'},
#   {'image': '/static/collections/garden-and-forest/images/featured-advertisements-7-310.jpg',
#    'title': 'Advertisements (Garden and Forest Vol. 7, Issue 310)',
#    'url': '/resource/gdclccn.05040093_v07/?sp=89'},
#   {'image': '/static/collections/garden-and-forest/images/featured-old-bridge-wrentham-mass.jpg',
#    'title': 'An Old Bridge in Wrentham, Massachusetts (Garden and Forest Vol. 8, Issue 362)',
#    'url': '/resource/gdclccn.05040093_v08/?sp=73'},
#   {'image': '/static/collections/garden-and-forest/images/featured-chrysanthemum.jpg',
#    'title': 'Chrysanthemum, Mayflower (Garden and Forest Vol. 9, Issue 414)',
#    'url': '/resource/gdclccn.05040093_v09/?sp=81'}],
#  'form_facets': {},
#  'next': {'active': False,
#   'children': [{'content': 'articles-and-essays/history-of-the-resource/index.html',
#     'link': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/',
#     'slug': 'digitizing-and-delivery-history-of-the-resource',
#     'title': 'Digitizing and Delivery – The History of the Resource at the Library of Congress and the University of Michigan',
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/'},
#    {'content': 'articles-and-essays/historical-background-of-garden-and-forest/index.html',
#     'link': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/',
#     'meta_description': "<em>Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry</em> made its debut on February 29, 1888, and ceased publication on December 29, 1897. Although financially strapped from the beginning, <em>Garden and Forest</em>'s influence spread far beyond its small circulation and brief ten-year run.",
#     'slug': 'historical-background-of-garden-and-forest',
#     'title': 'Historical Background of <em>Garden and Forest</em>',
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/'},
#    {'content': 'articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/index.html',
#     'link': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/',
#     'meta_description': "Credit for the graceful prose and for the eloquent advocacy for public parks should go not to Charles Sprague Sargent, but to Garden and Forest's editor William Stiles.",
#     'slug': 'william-augustus-stiles-editor-of-garden-and-forest',
#     'title': '"Master of a Felicitous English Style": William Augustus Stiles, Editor of <em>Garden and Forest</em>',
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/'},
#    {'content': 'articles-and-essays/garden-and-forest-and-landscape-art/index.html',
#     'link': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/',
#     'meta_description': 'Laura Wood Roper notes in her 1973 biography of Frederick Law Olmsted that the 1890s were years of "staggering reverses" for the profession of landscape architecture. But it was also during this period that a body of theory and technical expertise was developed and became the basis for training landscape architects.',
#     'slug': 'garden-and-forest-and-landscape-art',
#     'title': '<em>Garden and Forest</em> and "Landscape Art"',
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/'},
#    {'content': 'articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/index.html',
#     'link': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/',
#     'meta_description': "<em>Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry</em>, the brainchild of the Arnold Arboretum's first director, Charles Sprague Sargent, was published during a period (1888–1897) when the science of everything that grows—wild or cultivated—was still (barely) considered a single discipline.",
#     'slug': 'influence-of-garden-and-forest-on-the-development-of-horticulture',
#     'title': 'The Influence of <em>Garden and Forest</em> on the Development of Horticulture',
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/'},
#    {'content': 'articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/index.html',
#     'link': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/',
#     'meta_description': 'While acknowledging that it was a "first-rate publication," deftly edited by the talented journalist William A. Stiles, and conceding that it was "an immediate success," Stephanne B. Sutton also contrasted the effusive praise it received with its lack of "popularity"; the plaudits may have been "gratifying," but a larger circulation would have eased the journal\'s incessant "financial crisis."',
#     'slug': 'high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry',
#     'title': 'A High-grade Paper: Garden & Forest and Nineteenth-Century American Forestry',
#     'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/'},
#    {'content': 'articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/index.html',
#     'link': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/',
#     'meta_description': 'On February 29, 1888, the weekly periodical, Garden and Forest, A Journal of Horticulture, Landscape Art and Forestry, was inaugurated. Rather oddly, the statement outlining the purpose of the new publication, along with an extensive list of future contributors, was relegated to a page in the advertising section that preceded the main text.',
#     'slug': 'garden-and-forest-the-botanical-basis-of-it-all',
#     'title': 'Garden and Forest: The Botanical Basis of It All',
# ...
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:11:38.733Z',
#    'group': ['collections-portal'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/about-this-collection/',
#    'image_url': ['https://www.loc.gov/static/collections/garden-and-forest/500_500.jpg'],
#    'index': 2,
#    'item': {'call_number': ['SB1 .G2'],
#     'contributors': ['Sargent, Charles Sprague, 1841-1927, editor'],
#     'created_published': ['New York, Garden and Forest Pub. Co., 1888-1897.'],
#     'date': '1888',
#     'format': ['periodical'],
#     'genre': ['Periodicals'],
#     'language': ['eng'],
#     'medium': ['10 volumes illustrations 32 cm'],
#     'notes': ['Weekly',
#      'v. 1-10; Feb. 20, 1888-Dec. 29, 1897.',
#      'Volumes for Feb. 20, 1888- conducted by Charles S. Sargent.',
#      'Digitized images of the entire run of this serial are available via the Internet.'],
#     'subjects': ['Botany--Periodicals',
#      'Gardening--Periodicals',
#      'Forests and forestry--Periodicals',
#      'Botany',
#      'Forests and forestry',
#      'Gardening'],
#     'summary': ['"A journal of horticulture, landscape art, and forestry."'],
#     'title': 'Garden and forest'},
#    'items': 'https://www.loc.gov/collections/garden-and-forest/',
#    'language': ['english'],
#    'number': ['4753674', '2023-12-17t10:38:21', '0889-874x', '05040093'],
#    'number_issn': ['0889-874x'],
#    'number_lccn': ['05040093'],
#    'number_oclc': ['4753674'],
#    'number_source_modified': ['2023-12-17t10:38:21'],
#    'original_format': ['collection'],
#    'other_title': [],
#    'partof': ['digital collections',
#     'science, technology and business division',
#     'garden and forest'],
#    'publication_frequency': ['weekly'],
#    'resources': [],
#    'shelf_id': '~/collections/garden-and-forest/about-this-collection/',
#    'subject': ['horticulture',
#     'botany',
#     'park development',
#     'gardening',
#     'forests and forestry',
#     'science',
#     'science & technology',
#     'periodicals',
#     'landscape design',
#     'art & architecture'],
#    'subject_topic': ['science & technology', 'art & architecture'],
#    'timestamp': '2024-02-13T09:40:08.880Z',
#    'title': 'Garden and Forest',
#    'type': ['collection'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/about-this-collection/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/about-this-collection/rights-and-access/'],
#    'campaigns': [],
#    'description': ['The original Garden and Forest scans in this collection are in the public domain. The Library has obtained permission for the use of the essays in the collection, which may be subject to copyright.'],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/about-this-collection/rights-and-access/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 3,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/about-this-collection/rights-and-access/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': 'Rights and Access',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/about-this-collection/rights-and-access/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/'],
#    'campaigns': [],
#    'description': ['Top of page Skip to main content Library of Congress Search Everything Audio Recordings Books/Printed Material Films, Videos Legislation Manuscripts/Mixed Material Maps Notated Music Newspapers Periodicals Personal Narratives Photos, Prints, Drawings Software, E-Resources Web Archives'],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 4,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/articles-and-essays/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': 'Articles and Essays',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/'],
#    'campaigns': [],
#    'description': ["Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry was the first digital reformatting project done by the Library of Congress's Preservation Reformatting Division. It was also the first serial digitized in its entirety by LC. This digital-reformatting project represented the addition of digital technology to the list of options available for crafting preservation strategies for Library collections."],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 5,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': 'Digitizing and Delivery – The History of the Resource at the Library of Congress and the University of Michigan',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/digitizing-and-delivery-history-of-the-resource/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/'],
#    'campaigns': [],
#    'description': ['Laura Wood Roper notes in her 1973 biography of Frederick Law Olmsted that the 1890s were years of "staggering reverses" for the profession of landscape architecture. But it was also during this period that a body of theory and technical expertise was developed and became the basis for training landscape architects.'],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 6,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': '<em>Garden and Forest</em> and "Landscape Art"',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-and-landscape-art/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/'],
#    'campaigns': [],
#    'description': ['On February 29, 1888, the weekly periodical, Garden and Forest, A Journal of Horticulture, Landscape Art and Forestry, was inaugurated. Rather oddly, the statement outlining the purpose of the new publication, along with an extensive list of future contributors, was relegated to a page in the advertising section that preceded the main text.'],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 7,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': 'Garden and Forest: The Botanical Basis of It All',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/garden-and-forest-the-botanical-basis-of-it-all/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/'],
#    'campaigns': [],
#    'description': ['While acknowledging that it was a "first-rate publication," deftly edited by the talented journalist William A. Stiles, and conceding that it was "an immediate success," Stephanne B. Sutton also contrasted the effusive praise it received with its lack of "popularity"; the plaudits may have been "gratifying," but a larger circulation would have eased the journal\'s incessant "financial crisis."'],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 8,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': 'A High-grade Paper: Garden & Forest and Nineteenth-Century American Forestry',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/high-grade-paper-garden-and-forest-and-nineteenth-century-american-forestry/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/'],
#    'campaigns': [],
#    'description': ["<em>Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry</em> made its debut on February 29, 1888, and ceased publication on December 29, 1897. Although financially strapped from the beginning, <em>Garden and Forest</em>'s influence spread far beyond its small circulation and brief ten-year run."],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 9,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': 'Historical Background of <em>Garden and Forest</em>',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/historical-background-of-garden-and-forest/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/'],
#    'campaigns': [],
#    'description': ["<em>Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry</em>, the brainchild of the Arnold Arboretum's first director, Charles Sprague Sargent, was published during a period (1888–1897) when the science of everything that grows—wild or cultivated—was still (barely) considered a single discipline."],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 10,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': 'The Influence of <em>Garden and Forest</em> on the Development of Horticulture',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/influence-of-garden-and-forest-on-the-development-of-horticulture/'},
#   {'access_restricted': False,
#    'aka': ['http://www.loc.gov/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/'],
#    'campaigns': [],
#    'description': ["Credit for the graceful prose and for the eloquent advocacy for public parks should go not to Charles Sprague Sargent, but to Garden and Forest's editor William Stiles."],
#    'digitized': True,
#    'extract_timestamp': '2024-02-13T06:24:29.053Z',
#    'group': ['cms', 'managed-content'],
#    'hassegments': False,
#    'id': 'http://www.loc.gov/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/',
#    'image_url': ['https://www.loc.gov/static/images/favicons/open-graph-logo.png'],
#    'index': 11,
#    'language': ['english'],
#    'original_format': ['web page'],
#    'other_title': [],
#    'partof': ['garden and forest'],
#    'shelf_id': '~/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/',
#    'site': ['cms'],
#    'timestamp': '2024-02-13T09:41:03.181Z',
#    'title': '"Master of a Felicitous English Style": William Augustus Stiles, Editor of <em>Garden and Forest</em>',
#    'type': ['web page'],
#    'url': 'https://www.loc.gov/collections/garden-and-forest/articles-and-essays/william-augustus-stiles-editor-of-garden-and-forest/'}],
#  'search': {'dates': None,
#   'facet_limits': '',
#   'field': None,
#   'hits': 11,
#   'in': 'partof:garden and forest',
#   'query': '',
#   'recommended': 0,
#   'site': {},
#   'sort_by': None,
#   'type': 'search',
#   'union_facets': '',
#   'url': 'https://www.loc.gov/collections/garden-and-forest/?fo=json'},
#  'shards': ['01'],
#  'site_type': 'collections',
#  'subjects': ['Horticulture',
#   'Forests and forestry',
#   'Park Development',
#   'Botany',
#   'Landscape Design',
#   'Gardening',
#   'Science'],
#  'timestamp': 1707872779547,
#  'title': 'Garden and Forest',
#  'topics': ['Science & Technology', 'Art & Architecture'],
#  'total': 117,
#  'views': {'brief': 'https://www.loc.gov/collections/garden-and-forest/?fo=json&st=brief',
#   'current': 'list',
#   'gallery': 'https://www.loc.gov/collections/garden-and-forest/?fo=json&st=gallery',
#   'grid': 'https://www.loc.gov/collections/garden-and-forest/?fo=json&st=grid',
#   'list': 'https://www.loc.gov/collections/garden-and-forest/?fo=json',
#   'slideshow': 'https://www.loc.gov/collections/garden-and-forest/?fo=json&st=slideshow'}}

# %% [markdown]
# How many items were digitized in this colelction?

# %%
print(garden_forest["digitized"])
# Out:
# 117

# %% [markdown]
# What division does this collection belong to?

# %%
print(garden_forest["partof"])
# Out:
# ['Science, Technology and Business Division']

# %% [markdown]
# Display subjects within the collection:

# %%
for item in garden_forest["subjects"]:
  print(item)
# Out:
# Horticulture
# Forests and forestry
# Park Development
# Botany
# Landscape Design
# Gardening
# Science

# %% [markdown]
# Display the titles within the collection:

# %%
for item in garden_forest["results"]:
  print(item["title"])
# Out:
# Garden and forest
# Garden and Forest
# Rights and Access
# Articles and Essays
# Digitizing and Delivery – The History of the Resource at the Library of Congress and the University of Michigan
# <em>Garden and Forest</em> and "Landscape Art"
# Garden and Forest: The Botanical Basis of It All
# A High-grade Paper: Garden & Forest and Nineteenth-Century American Forestry
# Historical Background of <em>Garden and Forest</em>
# The Influence of <em>Garden and Forest</em> on the Development of Horticulture
# "Master of a Felicitous English Style": William Augustus Stiles, Editor of <em>Garden and Forest</em>

# %% [markdown]
# Display the descriptions of collection items:

# %%
for item in garden_forest["results"]:
  print(item["title"])
  print(item["description"], "\n")
# Out:
# Garden and forest
# ['"A journal of horticulture, landscape art, and forestry."']
#
# Garden and Forest
# ['Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry (1888-1897) was the first American journal devoted to horticulture, botany, landscape design and preservation, national and urban park development, scientific forestry, and the conservation of forest resources. The journal was established by Charles Sprague Sargent (1841-1927), the founding director of the Arnold Arboretum of Harvard University. Though the journal was published independently, Sargent considered the weekly magazine the organ of the Arboretum.']
#
# Rights and Access
# ['The original Garden and Forest scans in this collection are in the public domain. The Library has obtained permission for the use of the essays in the collection, which may be subject to copyright.']
#
# Articles and Essays
# ['Top of page Skip to main content Library of Congress Search Everything Audio Recordings Books/Printed Material Films, Videos Legislation Manuscripts/Mixed Material Maps Notated Music Newspapers Periodicals Personal Narratives Photos, Prints, Drawings Software, E-Resources Web Archives']
#
# Digitizing and Delivery – The History of the Resource at the Library of Congress and the University of Michigan
# ["Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry was the first digital reformatting project done by the Library of Congress's Preservation Reformatting Division. It was also the first serial digitized in its entirety by LC. This digital-reformatting project represented the addition of digital technology to the list of options available for crafting preservation strategies for Library collections."]
#
# <em>Garden and Forest</em> and "Landscape Art"
# ['Laura Wood Roper notes in her 1973 biography of Frederick Law Olmsted that the 1890s were years of "staggering reverses" for the profession of landscape architecture. But it was also during this period that a body of theory and technical expertise was developed and became the basis for training landscape architects.']
#
# Garden and Forest: The Botanical Basis of It All
# ['On February 29, 1888, the weekly periodical, Garden and Forest, A Journal of Horticulture, Landscape Art and Forestry, was inaugurated. Rather oddly, the statement outlining the purpose of the new publication, along with an extensive list of future contributors, was relegated to a page in the advertising section that preceded the main text.']
#
# A High-grade Paper: Garden & Forest and Nineteenth-Century American Forestry
# ['While acknowledging that it was a "first-rate publication," deftly edited by the talented journalist William A. Stiles, and conceding that it was "an immediate success," Stephanne B. Sutton also contrasted the effusive praise it received with its lack of "popularity"; the plaudits may have been "gratifying," but a larger circulation would have eased the journal\'s incessant "financial crisis."']
#
# Historical Background of <em>Garden and Forest</em>
# ["<em>Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry</em> made its debut on February 29, 1888, and ceased publication on December 29, 1897. Although financially strapped from the beginning, <em>Garden and Forest</em>'s influence spread far beyond its small circulation and brief ten-year run."]
#
# The Influence of <em>Garden and Forest</em> on the Development of Horticulture
# ["<em>Garden and Forest: A Journal of Horticulture, Landscape Art, and Forestry</em>, the brainchild of the Arnold Arboretum's first director, Charles Sprague Sargent, was published during a period (1888–1897) when the science of everything that grows—wild or cultivated—was still (barely) considered a single discipline."]
#
# "Master of a Felicitous English Style": William Augustus Stiles, Editor of <em>Garden and Forest</em>
# ["Credit for the graceful prose and for the eloquent advocacy for public parks should go not to Charles Sprague Sargent, but to Garden and Forest's editor William Stiles."]

# %% [markdown]
# Import module to display images:

# %%
from IPython.display import Image, display

# %% [markdown]
# Display front cover of collection items:

# %%
for item in garden_forest["results"]:
  print(item["title"])
  display(Image(url=item["image_url"][0]))
# Out:
# Garden and forest
# <img src="https://tile.loc.gov/image-services/iiif/service:gdc:gdclccn:05:04:00:93:_v:01:05040093_v01:0001/full/pct:6.25/0/default.jpg"/>
# Garden and Forest
# <img src="https://www.loc.gov/static/collections/garden-and-forest/500_500.jpg"/>
# Rights and Access
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
# Articles and Essays
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
# Digitizing and Delivery – The History of the Resource at the Library of Congress and the University of Michigan
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
# <em>Garden and Forest</em> and "Landscape Art"
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
# Garden and Forest: The Botanical Basis of It All
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
# A High-grade Paper: Garden & Forest and Nineteenth-Century American Forestry
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
# Historical Background of <em>Garden and Forest</em>
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
# The Influence of <em>Garden and Forest</em> on the Development of Horticulture
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
# "Master of a Felicitous English Style": William Augustus Stiles, Editor of <em>Garden and Forest</em>
# <img src="https://www.loc.gov/static/images/favicons/open-graph-logo.png"/>
